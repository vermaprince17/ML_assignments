# %% [markdown]
# # Name : Prince Verma
# # GitHub UserName: vermaprince17
# # USC-ID : 7468967920
# # USC Net ID: princeve

# %%
import numpy as np
import pandas as pd
import seaborn as sea
from matplotlib import pyplot as plt
import scipy.stats as stats
import operator
from beautifultable import BeautifulTable

import glob

# %%
COMMON_PATH = "../data/AReM/"

#number of directories is the number of classes for classification
directories = glob.glob(COMMON_PATH + "/*")
dir_names = [directory.split("/")[-1] for directory in directories]

columns = ["avg_rss12", "var_rss12", "avg_rss13", "var_rss13", "avg_rss23", "var_rss23"]

# %%
def read_data(PATH):
    '''
    Given the root folder path containg the dataset (AeRM),
    stores the data in DF's and returns a dict.
    ret: dict(filename: str, data: pd.DataFrame)
    '''
    time_series_data= {}
    TOTAL_PATH = PATH + "/*/*.csv"
    
    for path in glob.glob(TOTAL_PATH):
        
        df = pd.read_csv(path, skiprows=4)
        if df.isna().values.any():
            temp_datas = []
            
            for key,row in df.iterrows():
                temp_data = row.iloc[0]
                temp_data = temp_data.strip().split(" ")
                temp_data = [float(ele) for ele in temp_data]
                temp_datas.append(temp_data)

            new_df = pd.DataFrame(temp_datas, columns= df.columns, dtype= float)
            new_df.drop(new_df.columns[[0]],axis = 1, inplace= True)

        else:
            df.drop(df.columns[[0]],axis = 1, inplace= True)
            new_df = df
        
        temp = path.split("/")[-1]
        dataset_num = ""
        for char in temp:
            if char.isdigit():
                dataset_num += char
                
        name = path.split("/")[-2] + "/" + "dataset_" + dataset_num+".csv"
        time_series_data[name] = new_df
    
    return time_series_data

# %% [markdown]
# # 1. Time Series Classification Part 1: Feature Creation/Extraction
#
# An interesting task in machine learning is classification of time series. In this problem, we will classify the activities of humans based on time series obtained by a Wireless Sensor Network.
#
# **(a) Download the AReM data from:** https://archive.ics.uci.edu/ml/datasets/Activity+Recognition+system+based+on+Multisensor+data+fusion+\%28AReM\%29 .The dataset contains 7 folders that represent seven types of activities. In each folder, there are multiple files each of which represents an instant of a human performing an activity. Each file containis 6 time series collected from activities of the same person, which are called avgrss12, varrss12, avgrss13, varrss13,vgrss23, and arrss23. There are 88 instances in the dataset, each of which contains 6 time series and each time series has 480 consecutive values.

# %% [markdown]
# # Data Processing

# %%
time_series_data = read_data(COMMON_PATH)

for name, df in time_series_data.items():
    print('******************************')
    print("file_name: ", name)
    print("data_shape:", df.shape)
    print("sample_data: ")
    print(df.head())
    print('******************************')
    print()

print("Total no. of dataset instances: ", len(time_series_data))
# Out:
# ******************************
# file_name:  bending1/dataset_7.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      42.00       0.00      18.50       0.50      12.00       0.00
# 1      42.00       0.00      18.00       0.00      11.33       0.94
# 2      42.75       0.43      16.75       1.79      18.25       0.43
# 3      42.50       0.50      16.75       0.83      19.00       1.22
# 4      43.00       0.82      16.25       0.83      18.00       0.00
# ******************************
#
# ******************************
# file_name:  bending1/dataset_6.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      41.25       1.30      24.00       0.00      32.33       0.94
# 1      41.00       1.00      22.50       1.12      33.50       0.87
# 2      44.25       0.83      21.75       0.83      31.50       1.50
# 3      45.00       0.00      20.00       1.22      30.00       0.00
# 4      45.25       0.43      15.25       2.86      30.50       0.50
# ******************************
#
# ******************************
# file_name:  bending1/dataset_4.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0
csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      39.50       0.50       4.33       1.25      12.00       0.00
# 1      39.50       0.50       7.00       0.00      12.33       0.47
# 2      39.50       0.50       6.33       2.49      11.75       0.43
# 3      39.67       0.47       8.75       1.30      12.67       0.47
# 4      39.50       0.50       5.00       0.71      11.75       0.43
# ******************************
#
# ******************************
# file_name:  lying/dataset_6.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      39.67       0.47       8.75       0.43      14.67       0.47
# 1      39.67       0.47       8.75       0.43      14.67       0.47
# 2      39.33       0.47       8.00       0.82      14.25       0.43
# 3      39.67       0.47       7.50       0.50      13.67       1.25
# 4      39.33       0.47       9.00       0.00      13.50       0.50
# ******************************
#
# ******************************
# file_name:  lying/dataset_4.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0       48.0        0.0        9.0       0.00       9.25       0.43
# 1       48.0        0.0        9.0       0.00       9.50       0.50
# 2       48.0        0.0       10.0       0.71      10.00       0.71
# 3       48.0        0.0        9.5       0.50       9.50       0.50
# 4       48.0        0.0       10.0       0.00      10.00       1.00
# ******************************
#
# ******************************
# file_name:  lying/dataset_5.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      39.50       0.50      12.00       0.00        0.0        0.0
# 1      39.75       0.83      13.00       0.00        0.0        0.0
# 2      40.00       1.00      12.67       0.47        0.0        0.0
# 3      40.00       0.71      12.50       0.50        1.0        0.0
# 4      40.00       0.82      12.50       0.87        1.5        0.5
# ******************************
#
# ******************************
# file_name:  lying/dataset_1.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0       29.0        0.0       9.00       0.71       8.50       0.50
# 1       29.0        0.0       8.00       0.71       8.50       0.50
# 2       29.0        0.0       8.00       0.71       8.00       1.00
# 3       28.5        0.5       8.25       0.43       8.75       0.43
# 4       29.0        0.0       8.75       1.09       9.00       0.00
# ******************************
#
# ******************************
# file_name:  lying/dataset_2.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      29.00       0.00       2.75       0.43      10.20       0.75
# 1      29.33       0.47       2.50       0.50      10.33       0.94
# 2      29.00       0.00       1.50       0.50      10.25       0.43
# 3      29.25       0.43       1.50       0.50      10.25       0.83
# 4      29.00       0.00       1.00       0.00      10.50       1.12
# ******************************
#
# ******************************
# file_name:  lying/dataset_3.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0       48.0        0.0       6.25       0.43       2.00       0.71
# 1       48.0        0.0       6.00       0.00       1.67       0.94
# 2       48.0        0.0       6.00       0.00       2.00       1.00
# 3       48.0        0.0       5.25       0.43       2.67       0.94
# 4       48.0        0.0       5.50       0.50       2.00       0.82
# ******************************
#
# ******************************
# file_name:  lying/dataset_10.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0       29.0        0.0       9.00       0.71       8.50       0.50
# 1       29.0        0.0       8.00       0.71       8.50       0.50
# 2       29.0        0.0       8.00       0.71       8.00       1.00
# 3       28.5        0.5       8.25       0.43       8.75       0.43
# 4       29.0        0.0       8.75       1.09       9.00       0.00
# ******************************
#
# ******************************
# file_name:  lying/dataset_11.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0       48.0        0.0       6.25       0.43       2.00       0.71
# 1       48.0        0.0       6.00       0.00       1.67       0.94
# 2       48.0        0.0       6.00       0.00       2.00       1.00
# 3       48.0        0.0       5.25       0.43       2.67       0.94
# 4       48.0        0.0       5.50       0.50       2.00       0.82
# ******************************
#
# ******************************
# file_name:  lying/dataset_13.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      39.50       0.
csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      40.25       1.48      15.50       3.91      20.00       1.22
# 1      42.25       0.43      15.33       2.49      16.00       1.63
# 2      35.25       4.44      14.00       4.32      17.25       4.82
# 3      33.75       2.49      19.50       2.06      18.25       1.79
# 4      35.00       3.16      18.75       5.67      15.00       2.12
# ******************************
#
# ******************************
# file_name:  cycling/dataset_9.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      41.67       0.47      17.67       2.87      14.50       2.06
# 1      42.00       2.12       9.67       6.34      14.75       2.49
# 2      35.75       1.79      13.75       3.03      18.50       4.09
# 3      34.25       4.02      17.75       1.09      16.25       3.70
# 4      36.50       4.33      14.75       1.09      12.67       4.92
# ******************************
#
# Total no. of dataset instances:  88

# %% [markdown]
# **1. (b) Keep datasets 1 and 2 in folders bending1 and bending 2, as well as datasets 1, 2, and 3 in other folders as test data and other datasets as train data.**

# %%
def train_test_data(time_series_data, data_type):
    '''
    creates the data according to above question
    returns a DataFrame
    '''
    final_data = {}
    if data_type == 'test':
        for name, df in time_series_data.items():
            dataset = name.split("/")[-1]
            dataset_folder = name.split("/")[0]
            
            dataset = dataset.split("_")[-1]
            dataset_num = int(dataset.split(".")[0])
            
            if dataset_folder == 'bending1' or dataset_folder == 'bending2':
                if dataset_num <= 2:
                    final_data[name] = df                
                else:
                    continue               
            else:
                if dataset_num <= 3:
                    final_data[name] = df
                else:
                    continue
    
    else:
        for name, df in time_series_data.items():
            dataset = name.split("/")[-1]
            dataset_folder = name.split("/")[0]
            
            dataset = dataset.split("_")[-1]
            dataset_num = int(dataset.split(".")[0])
            
            if dataset_folder == 'bending1' or dataset_folder == 'bending2':
                if dataset_num >= 3:
                    final_data[name] = df                
                else:
                    continue               
            else:
                if dataset_num >= 4:
                    final_data[name] = df
                else:
                    continue
        
    return final_data

# %%
test_data = train_test_data(time_series_data, 'test')

for name, df in test_data.items():
    print('******************************')
    print("file_name: ", name)
    print("data_shape:", df.shape)
    print("sample_data: ")
    print(df.head())
    print('******************************')
    print()

print("Total no. of dataset instances: ", len(test_data))
# Out:
# ******************************
# file_name:  bending1/dataset_1.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      39.25       0.43      22.75       0.43      33.75        1.3
# 1      39.25       0.43      23.00       0.00      33.00        0.0
# 2      39.25       0.43      23.25       0.43      33.00        0.0
# 3      39.50       0.50      23.00       0.71      33.00        0.0
# 4      39.50       0.50      24.00       0.00      33.00        0.0
# ******************************
#
# ******************************
# file_name:  bending1/dataset_2.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      43.67       0.47      24.75       0.43      30.00       0.00
# 1      43.33       0.47      25.33       0.47      30.00       0.00
# 2      42.75       0.83      25.25       0.83      30.50       0.50
# 3      41.75       0.43      20.50       3.35      30.75       0.83
# 4      42.50       0.50      20.75       4.55      31.75       0.43
# ******************************
#
# ******************************
# file_name:  walking/dataset_1.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      35.00       3.67      16.50       3.77      14.00       1.63
# 1      28.50       3.35      17.50       3.77      12.25       3.90
# 2      35.50       2.87      15.75       2.86      17.75       5.07
# 3      29.75      12.19      16.25       2.17      20.75       2.59
# 4      27.00       2.12      16.75       0.83      24.75       1.64
# ******************************
#
# ******************************
# file_name:  walking/dataset_2.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0
csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0       29.0        0.0       9.00       0.71       8.50       0.50
# 1       29.0        0.0       8.00       0.71       8.50       0.50
# 2       29.0        0.0       8.00       0.71       8.00       1.00
# 3       28.5        0.5       8.25       0.43       8.75       0.43
# 4       29.0        0.0       8.75       1.09       9.00       0.00
# ******************************
#
# ******************************
# file_name:  lying/dataset_2.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      29.00       0.00       2.75       0.43      10.20       0.75
# 1      29.33       0.47       2.50       0.50      10.33       0.94
# 2      29.00       0.00       1.50       0.50      10.25       0.43
# 3      29.25       0.43       1.50       0.50      10.25       0.83
# 4      29.00       0.00       1.00       0.00      10.50       1.12
# ******************************
#
# ******************************
# file_name:  lying/dataset_3.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0       48.0        0.0       6.25       0.43       2.00       0.71
# 1       48.0        0.0       6.00       0.00       1.67       0.94
# 2       48.0        0.0       6.00       0.00       2.00       1.00
# 3       48.0        0.0       5.25       0.43       2.67       0.94
# 4       48.0        0.0       5.50       0.50       2.00       0.82
# ******************************
#
# ******************************
# file_name:  cycling/dataset_1.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0       32.0       4.85      17.50       3.35      22.50       3.20
# 1       40.5       1.12      14.00       2.24      21.75       1.30
# 2       40.5       2.60      11.33       4.50      18.25       5.31
# 3       34.5       1.50      20.67       2.87      19.00       2.83
# 4       34.5       1.50      21.25       3.27      18.25       4.38
# ******************************
#
# ******************************
# file_name:  cycling/dataset_2.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      41.75       1.79       8.75       6.87      23.25       0.83
# 1      39.50       3.57      15.00       0.00      19.25       3.27
# 2      35.00       1.41      19.33       1.25      19.50       3.20
# 3      36.00       0.00      18.50       0.50      21.25       4.76
# 4      33.33       2.87      20.25       1.79      23.75       0.43
# ******************************
#
# ******************************
# file_name:  cycling/dataset_3.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      35.50       3.84      19.75       2.77      20.25       3.27
# 1      33.50      12.99      16.50       4.72      22.50       1.50
# 2      42.00       0.00       9.00       3.67      20.25       1.30
# 3      41.50       1.50      12.33       0.47      18.00       2.45
# 4      35.25       2.49      19.50       3.35      24.25       0.43
# ******************************
#
# Total no. of dataset instances:  19

# %%
train_data = train_test_data(time_series_data, 'train')

for name, df in train_data.items():
    print('******************************')
    print("file_name: ", name)
    print("data_shape:", df.shape)
    print("sample_data: ")
    print(df.head())
    print('******************************')
    print()

print("Total no. of dataset instances: ", len(train_data))
# Out:
# ******************************
# file_name:  bending1/dataset_7.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      42.00       0.00      18.50       0.50      12.00       0.00
# 1      42.00       0.00      18.00       0.00      11.33       0.94
# 2      42.75       0.43      16.75       1.79      18.25       0.43
# 3      42.50       0.50      16.75       0.83      19.00       1.22
# 4      43.00       0.82      16.25       0.83      18.00       0.00
# ******************************
#
# ******************************
# file_name:  bending1/dataset_6.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      41.25       1.30      24.00       0.00      32.33       0.94
# 1      41.00       1.00      22.50       1.12      33.50       0.87
# 2      44.25       0.83      21.75       0.83      31.50       1.50
# 3      45.00       0.00      20.00       1.22      30.00       0.00
# 4      45.25       0.43      15.25       2.86      30.50       0.50
# ******************************
#
# ******************************
# file_name:  bending1/dataset_4.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0
csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0       29.0        0.0       9.00       0.71       8.50       0.50
# 1       29.0        0.0       8.00       0.71       8.50       0.50
# 2       29.0        0.0       8.00       0.71       8.00       1.00
# 3       28.5        0.5       8.25       0.43       8.75       0.43
# 4       29.0        0.0       8.75       1.09       9.00       0.00
# ******************************
#
# ******************************
# file_name:  lying/dataset_11.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0       48.0        0.0       6.25       0.43       2.00       0.71
# 1       48.0        0.0       6.00       0.00       1.67       0.94
# 2       48.0        0.0       6.00       0.00       2.00       1.00
# 3       48.0        0.0       5.25       0.43       2.67       0.94
# 4       48.0        0.0       5.50       0.50       2.00       0.82
# ******************************
#
# ******************************
# file_name:  lying/dataset_13.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      39.50       0.50       4.33       1.25      12.00       0.00
# 1      39.50       0.50       7.00       0.00      12.33       0.47
# 2      39.50       0.50       6.33       2.49      11.75       0.43
# 3      39.67       0.47       8.75       1.30      12.67       0.47
# 4      39.50       0.50       5.00       0.71      11.75       0.43
# ******************************
#
# ******************************
# file_name:  lying/dataset_12.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      39.50       0.50      12.00       0.00        0.0        0.0
# 1      39.75       0.83      13.00       0.00        0.0        0.0
# 2      40.00       1.00      12.67       0.47        0.0        0.0
# 3      40.00       0.71      12.50       0.50        1.0        0.0
# 4      40.00       0.82      12.50       0.87        1.5        0.5
# ******************************
#
# ******************************
# file_name:  lying/dataset_15.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0       29.0        0.0       9.00       0.71       8.50       0.50
# 1       29.0        0.0       8.00       0.71       8.50       0.50
# 2       29.0        0.0       8.00       0.71       8.00       1.00
# 3       28.5        0.5       8.25       0.43       8.75       0.43
# 4       29.0        0.0       8.75       1.09       9.00       0.00
# ******************************
#
# ******************************
# file_name:  lying/dataset_14.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      39.67       0.47       6.00       0.82      16.00       1.00
# 1      39.50       0.50       4.50       1.12      17.75       0.43
# 2      39.67       0.47       4.50       1.12      18.33       0.47
# 3      39.50       0.50       4.50       2.06      17.50       0.50
# 4      39.33       0.47       5.33       0.47      17.00       0.71
# ******************************
#
# ******************************
# file_name:  lying/dataset_8.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      39.58       0.49       1.92       0.73      17.67       0.47
# 1      39.25       0.43       2.00       0.71      17.75       0.43
# 2      39.25       0.43       1.67       0.94      17.67       0.47
# 3      39.50       0.50       2.67       0.47      17.75       0.43
# 4      39.50       0.50       1.00       0.00      17.75       0.43
# ******************************
#
# ******************************
# file_name:  lying/dataset_9.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      39.67       0.47       6.00       0.82      16.00       1.00
# 1      39.50       0.50       4.50       1.12      17.75       0.43
# 2      39.67       0.47       4.50       1.12      18.33       0.47
# 3      39.50       0.50       4.50       2.06      17.50       0.50
# 4      39.33       0.47       5.33       0.47      17.00       0.71
# ******************************
#
# ******************************
# file_name:  cycling/dataset_7.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      32.50       3.50       9.75       2.28      18.50       1.66
# 1      39.00       0.82      11.33       4.92      16.50       0.50
# 2      42.50       0.50      17.75       2.68      19.67       3.09
# 3      35.75       6.26      12.67       1.70      13.75       8.23
# 4      34.50       1.50      14.50       1.66      10.75       6.91
# ******************************
#
# ******************************
# file_name:  cycling/dataset_6.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0
csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      40.25       1.48      15.50       3.91      20.00       1.22
# 1      42.25       0.43      15.33       2.49      16.00       1.63
# 2      35.25       4.44      14.00       4.32      17.25       4.82
# 3      33.75       2.49      19.50       2.06      18.25       1.79
# 4      35.00       3.16      18.75       5.67      15.00       2.12
# ******************************
#
# ******************************
# file_name:  cycling/dataset_9.csv
# data_shape: (480, 6)
# sample_data:
#    avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0      41.67       0.47      17.67       2.87      14.50       2.06
# 1      42.00       2.12       9.67       6.34      14.75       2.49
# 2      35.75       1.79      13.75       3.03      18.50       4.09
# 3      34.25       4.02      17.75       1.09      16.25       3.70
# 4      36.50       4.33      14.75       1.09      12.67       4.92
# ******************************
#
# Total no. of dataset instances:  69

# %% [markdown]
# **1. (c) Feature Extraction**
#
# Classification of time series usually needs extracting features from them. In this
# problem, we focus on time-domain features.
#
# **(i)Research what types of time-domain features are usually used in time series
# classification and list them (examples are minimum, maximum, mean, etc).**

# %% [markdown]
# # Some of the Time Domain features used in time-series classification are:
#
# 1. Mean value of the time series
# 2. Median value of the time series
# 3. Standard deviation of the time series
# 4. Minimum and maximum value of the time series
# 5. Kurtosis or skewness of the time series
# 6. Auto correlation
# 7. Cross correlation
# 8. Moving average component of the time series
# 9. Auto regressive component of the time series
# 10. Number of positive and negative peaks in the time series.

# %% [markdown]
# **1. (c) (ii) Extract the time-domain features minimum, maximum, mean, median, standard deviation, first quartile, and third quartile for all of the 6 time series
# in each instance. You are free to normalize/standardize features or use them directly.**

# %%
dir_names = ['bending1','bending2','cycling','lying','sitting','standing','walking']
dataset = [7,6,15,15,15,15,15] # no of datasets in each folder

parameters = ['Min', 'Max', 'Mean', 'Median', 'Std', 'First_quartile', 'Third_quartile']

stats = {}
stats["file_name"] = []
for col in columns:
    for param in parameters:
        stats[param + "_" + col] = []
        
for i, activity in enumerate(dir_names):
    for dataset_num in range(1, dataset[i]+1):
        
        file_name = activity + "/dataset_" + str(dataset_num) + ".csv"
        df = time_series_data[file_name]
        
        stats["file_name"].append(file_name) 
        for col in df.columns:
            feature = pd.DataFrame(df[col])
                
            stats["Min_"+col].append(np.min(feature)[col])
            stats["Max_"+col].append(np.max(feature)[col])
            stats["Mean_"+col].append(np.mean(feature)[col])
            stats["Median_"+col].append(np.median(feature))
            stats["Std_"+col].append(np.std(feature)[col])
            stats["First_quartile_"+col].append(np.quantile(feature, 0.25))
            stats["Third_quartile_"+col].append(np.quantile(feature, 0.75))        
    
time_domain_stats = pd.DataFrame.from_dict(stats)
time_domain_stats

# Please Scroll left to right since there are 42 + 1 features present.

# to match all the 88 rows outputs 
# run -> 
# pd.set_option('display.max_rows', None); # displays all the 88 rows
# time_domain_stats
# Out:
#                  file_name  Min_avg_rss12  Max_avg_rss12  Mean_avg_rss12  \
# 0   bending1/dataset_1.csv          37.25          45.00       40.624792
# 1   bending1/dataset_2.csv          38.00          45.67       42.812812
# 2   bending1/dataset_3.csv          35.00          47.40       43.954500
# 3   bending1/dataset_4.csv          33.00          47.75       42.179813
# 4   bending1/dataset_5.csv          33.00          45.75       41.678063
# ..                     ...            ...            ...             ...
# 83  walking/dataset_11.csv          19.50          45.33       33.586875
# 84  walking/dataset_12.csv          19.75          45.50       34.322750
# 85  walking/dataset_13.csv          19.50          46.00       34.546229
# 86  walking/dataset_14.csv          23.50          46.25       34.873229
# 87  walking/dataset_15.csv          19.25          44.00       34.473188
#
#     Median_avg_rss12  Std_avg_rss12  First_quartile_avg_rss12  \
# 0              40.50       1.475428                     39.25
# 1              42.50       1.434054                     42.00
# 2              44.33       1.557210                     43.00
# 3              43.50       3.666840                     39.15
# 4              41.75       2.241152                     41.33
# ..               ...            ...                       ...
# 83             34.25       4.646088                     30.25
# 84             35.25       4.747524                     31.00
# 85             35.25       4.837247                     31.25
# 86             35.25       4.526997                     31.75
# 87             35.00       4.791706                     31.25
#
#     Third_quartile_avg_rss12  Min_var_rss12  Max_var_rss12  ...  \
# 0                    42.0000            0.0           1.30  ...
# 1                    43.6700            0.0           1.22  ...
# 2                    45.0000            0.0           1.70  ...
# 3                    45.0000            0.0           3.00  ...
# 4                    42.7500            0.0           2.83  ...
# ..                       ...            ...            ...  ...
# 83                   37.0000            0.0          14.67  ...
# 84                   38.0000            0.0          13.47  ...
# 85                   37.8125            0.0          12.47  ...
# 86                   38.2500            0.0          14.82  ...
# 87                   38.0000            0.0          13.86  ...
#
#     Std_avg_rss23  First_quartile_avg_rss23  Third_quartile_avg_rss23  \
# 0        2.186168                   33.0000                     36.00
# 1        1.993175                   32.0000                     34.50
# 2        1.997520                   35.3625                     36.50
# 3        3.845436                   30.4575                     36.33
# 4        2.408514                   28.4575                     31.25
# ..            ...                       ...                       ...
# 83       3.280561                   13.7300                     18.25
# 84       3.116605                   13.5000                     17.75
# 85       2.820182                   14.0000                     17.75
# 86       3.127813                   13.7500                     18.00
# 87       3.153030                   13.7300                     17.75
#
#     Min_var_rss23  Max_var_rss23  Mean_var_rss23  Median_var_rss23  \
# 0            0.00           1.92        0.570583              0.43
# 1            0.00           3.11        0.571083              0.43
# 2            0.00           1.79        0.493292              0.43
# 3            0.00           2.18        0.613521              0.50
# 4            0.00           1.79        0.383292              0.43
# ..            ...            ...             ...               ...
# 83           0.00           8.32        3.259729              3.11
# 84           0.00           9.67        3.432562              3.20
# 85           0.00          10.00        3.338125              3.08
# 86           0.00           9.51        3.424646              3.27
# 87           0.43           9.00        3.340458              3.09
#
#     Std_var_rss23  First_quartile_var_rss23  Third_quartile_var_rss23
# 0        0.582308                    0.0000                    1.3000
# 1        0.600383                    0.0000                    1.3000
# 2        0.512971                    0.0000                    0.9400
# 3        0.523771                    0.0000                    1.0000
# 4        0.388759                    0.0000                    0.5000
# ..            ...                       ...                       ...
# 83       1.638534                    2.0500                    4.3225
# 84       1.730921                    2.1575                    4.5650
# 85       1.655016                    2.1600                    4.3350
# 86       1.689198                    2.1700                    4.5000
# 87       1.697343                    2.1200                    4.3750
#
# [88 rows x 43 columns]

# %% [markdown]
# **1. (c) (iii) Estimate the standard deviation of each of the time-domain features you extracted from the data. Then, use Python’s bootstrapped or any other
# method to build a 90% bootsrap confidence interval for the standard deviation of each feature**

# %%
# Standard deivation of each of the above feature

std = time_domain_stats.std()
output_std_42_feature = pd.DataFrame(std, columns= ["Standard Deviation"])
output_std_42_feature
# Out:
#                           Standard Deviation
# Min_avg_rss12                       9.569975
# Max_avg_rss12                       4.394362
# Mean_avg_rss12                      5.335718
# Median_avg_rss12                    5.440054
# Std_avg_rss12                       1.770306
# First_quartile_avg_rss12            6.153590
# Third_quartile_avg_rss12            5.138925
# Min_var_rss12                       0.000000
# Max_var_rss12                       5.062729
# Mean_var_rss12                      1.574164
# Median_var_rss12                    1.412244
# Std_var_rss12                       0.883184
# First_quartile_var_rss12            0.946386
# Third_quartile_var_rss12            2.125266
# Min_avg_rss13                       2.956462
# Max_avg_rss13                       4.875137
# Mean_avg_rss13                      4.008380
# Median_avg_rss13                    4.036396
# Std_avg_rss13                       0.945724
# First_quartile_avg_rss13            4.220658
# Third_quartile_avg_rss13            4.171628
# Min_var_rss13                       0.000000
# Max_var_rss13                       2.183625
# Mean_var_rss13                      1.166114
# Median_var_rss13                    1.145586
# Std_var_rss13                       0.457764
# First_quartile_var_rss13            0.843620
# Third_quartile_var_rss13            1.552504
# Min_avg_rss23                       6.124001
# Max_avg_rss23                       5.741238
# Mean_avg_rss23                      5.675593
# Median_avg_rss23                    5.813782
# Std_avg_rss23                       1.023830
# First_quartile_avg_rss23            6.096465
# Third_quartile_avg_rss23            5.531720
# Min_var_rss23                       0.045838
# Max_var_rss23                       2.518921
# Mean_var_rss23                      1.154812
# Median_var_rss23                    1.086474
# Std_var_rss23                       0.517078
# First_quartile_var_rss23            0.758584
# Third_quartile_var_rss23            1.523599

# %% [markdown]
# **90% bootsrap confidence interval for the standard deviation of each feature**

# %%
import bootstrapped.bootstrap as boot
import bootstrapped.stats_functions as boot_stats

# %%
temp = []
for feature in time_domain_stats.columns.to_list():
    if feature == 'file_name':
        continue
    
    samples = np.array(time_domain_stats[feature])
    res = boot.bootstrap(samples, stat_func= boot_stats.std, alpha= 0.1)
    temp.append([feature, np.std(samples), res.lower_bound, res.upper_bound])

ans = pd.DataFrame(temp, columns= ['feature_name', 'standard_deviation',
                                   'lower_confidence_interval', 'upper_confidence_interval'])


ans
# Out:
#                 feature_name  standard_deviation  lower_confidence_interval  \
# 0              Min_avg_rss12            9.515445                   8.303564
# 1              Max_avg_rss12            4.369322                   3.482179
# 2             Mean_avg_rss12            5.305314                   4.760074
# 3           Median_avg_rss12            5.409056                   4.853968
# 4              Std_avg_rss12            1.760219                   1.587432
# 5   First_quartile_avg_rss12            6.118526                   5.633919
# 6   Third_quartile_avg_rss12            5.109643                   4.409009
# 7              Min_var_rss12            0.000000                   0.000000
# 8              Max_var_rss12            5.033882                   4.698205
# 9             Mean_var_rss12            1.565194                   1.431396
# 10          Median_var_rss12            1.404197                   1.270606
# 11             Std_var_rss12            0.878152                   0.819295
# 12  First_quartile_var_rss12            0.940994                   0.853034
# 13  Third_quartile_var_rss12            2.113157                   1.940319
# 14             Min_avg_rss13            2.939616                   2.787993
# 15             Max_avg_rss13            4.847358                   4.243816
# 16            Mean_avg_rss13            3.985540                   3.503257
# 17          Median_avg_rss13            4.013397                   3.516633
# 18             Std_avg_rss13            0.940335                   0.764708
# 19  First_quartile_avg_rss13            4.196608                   3.708735
# 20  Third_quartile_avg_rss13            4.147858                   3.628082
# 21             Min_var_rss13            0.000000                   0.000000
# 22             Max_var_rss13            2.171183                   1.991594
# 23            Mean_var_rss13            1.159470                   1.104228
# 24          Median_var_rss13            1.139058                   1.083372
# 25             Std_var_rss13            0.455156                   0.427358
# 26  First_quartile_var_rss13            0.838813                   0.791741
# 27  Third_quartile_var_rss13            1.543658                   1.469349
# 28             Min_avg_rss23            6.089107                   4.692880
# 29             Max_avg_rss23            5.708524                   4.881823
# 30            Mean_avg_rss23            5.643253                   4.583452
# 31          Median_avg_rss23            5.780655                   4.673898
# 32             Std_avg_rss23            1.017996                   0.828137
# 33  First_quartile_avg_rss23            6.061727                   4.948620
# 34  Third_quartile_avg_rss23            5.500200                   4.511510
# 35             Min_var_rss23            0.045577                   0.013125
# 36             Max_var_rss23            2.504568                   2.262509
# 37            Mean_var_rss23            1.148232                   1.088121
# 38          Median_var_rss23            1.080284                   1.019586
# 39             Std_var_rss23            0.514132                   0.486828
# 40  First_quartile_var_rss23            0.754261                   0.704259
# 41  Third_quartile_var_rss23            1.514918                   1.438162
#
#     upper_confidence_interval
# 0                   10.810914
# 1                    5.434671
# 2                    5.934425
# 3                    6.045031
# 4                    1.956099
# 5                    6.703416
# 6                    5.926676
# 7                    0.000000
# 8                    5.459989
# 9                    1.746473
# 10                   1.575994
# 11                   0.959561
# 12                   1.059770
# 13                   2.341809
# 14                   3.135926
# 15                   5.538078
# 16                   4.582108
# 17                   4.630576
# 18                   1.121734
# 19                   4.778031
# 20                   4.776406
# 21                   0.000000
# 22                   2.384849
# 23                   1.248879
# 24                   1.228891
# 25                   0.492114
# 26                   0.908872
# 27                   1.660937
# 28                   7.804625
# 29                   6.691507
# 30                   6.875889
# 31                   7.057679
# 32                   1.230143
# 33                   7.371802
# 34                   6.668469
# 35                   0.091154
# 36                   2.772143
# 37                   1.241935
# 38                   1.172622
# 39                   0.552929
# 40                   0.822280
# 41                   1.636883

# %% [markdown]
# **1. (c) iv. Use your judgement to select the three most important time-domain features**

# %% [markdown]
# 1. Median - Its a good measure of central tendancy that is not affected by outliers.
# 2. Mean - Its a better measure of central tendancy when the data is continous and to capture the aggregate value.
# 3. Standard deviation - Its a measure of dispersion of the dataset.

# %% [markdown]
# # 2. ISLR 3.7.4

# %% [markdown]
# (a) The results would be similar. As we are increasing the flexibility of the model i.e going from linear to cubic regression and given that we have small no. of samples, the training error for cubic regression would be lesser compared to training error of linear regression (over fitting).

# %% [markdown]
# (b) Since the true relationship is linear, linear regression would slightly perform better than cubic regression on test RSS. Since the data points are closely linear, the cubic regression may fit close to linear relation (not wildly cubic).

# %% [markdown]
# (c) Clearly cubic regression would outperform linear regression since increasing model flexibility would decrease training error. Since the data is not linearly seperated the results in (a) were almost same, but in this case they would be different.

# %% [markdown]
# (d) The answer to this question would depend on how well the data is linearly or non linearly separated. If the data is wildly away from linear relationship, then a cubic regression would perform well on test RSS and vice versa. So there is not enough information to decide.

# %% [markdown]
# # 4. Time Series Classification Part 2: Binary and Multiclass Classification
